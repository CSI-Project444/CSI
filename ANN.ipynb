# %% [markdown]
# <a href="https://colab.research.google.com/github/CSI-Project444/CSI/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CSI-Project444/CSI/main/Data/ez1.csv')
df.sample(5)
# Out:
#       Zone  data  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 1924     1     6           5           7           5           7           5
# 7386     4     8          -8           8          -8           7          -8
# 349      1     2          10           3          10           4          10
# 4707     3     6           3           7           3           7           2
# 7318     4     6           7           6           6           7           6
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 95  Unnamed: 96  \
# 1924           7           5           7  ...            8            1
# 7386           8          -8           7  ...            3           -7
# 349            3          10           3  ...            3            6
# 4707           7           2           7  ...            7           -1
# 7318           7           6           6  ...            6            1
#
# ...

# %%
df[['pow2: 2','pow2: 3']] = np.power((df[['Unnamed: 2','Unnamed: 3']]),2)
print(df)
# Out:
#       Zone  data  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        1   -12          -6         -12          -6         -12          -5
# 1        1   -12           4         -11           5         -11           5
# 2        1   -11           5         -11           4         -11           5
# 3        1   -12           2         -11           2         -11           3
# 4        1    -5          10          -5          10          -4          10
# ...    ...   ...         ...         ...         ...         ...         ...
# 7937     4     3         -10           3         -10           2         -10
# 7938     4    -5          -9          -5          -9          -6          -9
# 7939     4   -10           2         -10           3         -10           3
# 7940     4     5          -9           4          -9           4          -9
# 7941     4    -3         -10          -4         -10          -4         -10
#
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
url='https://raw.githubusercontent.com/CSI-Project444/CSI/main/Data/ez1.csv'
df=pd.read_csv(url)
df.sample(5)
# Out:
#       Zone  data  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 7681     4     1         -10           0         -10           0         -10
# 3342     2    -4          10          -4          10          -4          10
# 3065     2   -10           8          -9           8          -9           8
# 5394     3     8          -8           7          -7           7          -8
# 7287     4     2         -11           1         -12           1         -11
#
#       Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  Unnamed: 95  Unnamed: 96  \
# 7681           0         -10           0  ...           -1           -8
# 3342          -4          10          -3  ...           -2            7
# 3065          -9           7          -9  ...           -5            5
# 5394           7          -7           7  ...            4           -5
# 7287           1         -12           1  ...            1           -7
#
# ...

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.preprocessing import OneHotEncoder
cols=['Unnamed: 2','Unnamed: 3','Unnamed: 4']
X=df[cols] 
scaler = StandardScaler()
X_scale=scaler.fit_transform(X)
X_scale = X_scale.round(4) 
y = np.array(df['Zone'])

encoder = OneHotEncoder()
y_targets = encoder.fit_transform(df[['Zone']]).toarray()

# %%
from sklearn.model_selection import train_test_split
test_size=0.6
X_train, X_test, y_train, y_test = train_test_split(
    X, y_targets, 
    test_size=test_size, random_state=4)

# %%
from keras.models import Sequential
from keras.layers.core import Dense
model = Sequential()
model.add(Dense(10, input_dim=3, activation='relu'))
model.add(Dense(10, input_dim=10, activation='relu'))
model.add(Dense(10, input_dim=10, activation='relu'))
model.add(Dense(3, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, verbose=1)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-9f69fece4b42> in <module>
# ----> 1 model.fit(X_train, y_train, epochs=100, verbose=1)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
# ...

# %%
results = model.evaluate(X_test, y_test)
print('Accuracy: %.3f' % results[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-8d8ca41a9015> in <module>
# ----> 1 results = model.evaluate(X_test, y_test)
#       2 print('Accuracy: %.3f' % results[1])
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in tf__test_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ...
